# %% [markdown]
# # **Introduction**

# %% [markdown]
# Data yang diperoleh dalam bentuk mentahan (raw), belum dapat di analisa / modelkan secara langsung karena memiliki beberapa permasalahan.
#
# 1. Terdapat missing value \
#    Missing value menandakan ketiadaan nilai. Hal ini berbeda dengan angka 0 atau string kosong (""). Missing value dapat disebabkan oleh beberapa hal:
#       - Kesalahan pengumpulan data
#       - Corrupt / error pada database
#       - Kesengajaan penghilangan data
#
# <img src="https://drive.google.com/uc?export=view&id=1GkOf6jiUQJOpNR2R5fd0yEFER4dSLW0R" alt="Drawing" width= 500px;/>
#
#  2. Terdapat Outlier \
#  Outlier merupakan nilai yang menyimpang dari rata-rata kebanyakan data.
#
# <img src="https://drive.google.com/uc?export=view&id=1aAyaBbnQ2Ywjcia-_NBW4k4lnkIWWSKO" alt="Drawing" width= 500px;/>
#
#  3. Terdapat data duplikat
#  Data duplikat terjadi karena adanya entry/record data yang sama
#
# <img src="https://drive.google.com/uc?export=view&id=1a6bAp_nOncXpgZdrHH0tHg-n_l4dyI9g" alt="Drawing" width= 500px;/>
#
#  4. Terdapat Inkonsistensi pada data \
#   Inkonsistensi direpresentasikan dengan data yang memiliki meaning yang sama namun ditulis secara berbeda.
#
# <img src="https://drive.google.com/uc?export=view&id=1q9EqPtG2yGRiPtFIMzVTOvS2QJNtLLa7" alt="Drawing" width= 500px;/>
#
# Permasalahan diatas, perlu di tangani terlebih dahulu sebelum masuk ke tahapan analisa / pemodelan data karena dapat berpengaruh ke hasil analisa dan interpretasi model. Pada materi kali ini, akan dipelajari cara menangani masalah pada data yang telah dijabarkan diatas

# %% [markdown]
# **Outline**
# - Handling Nan
# - Handling Outlier
# - Handling Duplicate
# - Handling Inkonsistent Format

# %% [markdown]
# ## **Topik**
#
# ---

# %% [markdown]
# ### **Subtopik 1 : Handling Missing Value**
#
# Rudi bekerja sebagai analis di sebuah agen properti. Dia meminta untuk menganalisis data properti yang dimiliki oleh perusahaan. Namun sebelum melakukukan analisis, dia diminta unutk membersihkan datanya terlebih dahulu agar hasil analisis bisa akurat.

# %%
# import library pandas
import pandas as pd

# %%
# read data property
property_data = pd.read_csv('https://raw.githubusercontent.com/ham407/Data-Cleansing-Using-Python/main/Datasets/property_data.csv')

# menampilkan semua data property
property_data
# Out:
#           lai  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  \
# 0   100001000     104      PUTNAM            Y           3.0       1.0
# 1   100002000     197         LXT            N           1.0       1.0
# 2   100003000     199   LEXINGTON            N           NaN       1.0
# 3   100004000     201    berkeley            Y           1.0       NaN
# 4   100004000     201    berkeley            Y           1.0       NaN
# 5   100005000     203    BERKELEY            Y           3.0       2.0
# 6   100006000     207    Berkeley            Y           NaN       1.0
# 7   100007000     209  WASHINGTON          NaN           2.0       1.0
# 8   100008000     213     TREMONT            Y           1.0       1.0
# 9   100009000     215     TREMONT            Y           NaN       2.0
# 10  100007000     209  WASHINGTON          NaN           2.0       1.0
#
#       SQ_FT
# 0     900.0
# 1       NaN
# 2     850.0
# 3     700.0
# 4     700.0
# 5     975.0
# 6     800.0
# 7     950.0
# 8       NaN
# 9   88000.0
# 10    950.0

# %% [markdown]
# Terlihat pada beberapa kolom berisi terdapat missing value (NaN). Sebelum menangani missing value, akan dilakukan pengecekan terlebih dahulu untuk melihat persentase missing value di tiap kolom.

# %% [markdown]
# #### **Identified Missing Value**

# %% [markdown]
# Untuk mengecek missing value dapat dilakukan dengan method menggunakan `isna()` atau `isnull()`

# %%
# mengecek missing value pada property_data menggunakan isnull()
property_data.isnull()
# Out:
#       lai  ST_NUM  ST_NAME  OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  SQ_FT
# 0   False   False    False         False         False     False  False
# 1   False   False    False         False         False     False   True
# 2   False   False    False         False          True     False  False
# 3   False   False    False         False         False      True  False
# 4   False   False    False         False         False      True  False
# 5   False   False    False         False         False     False  False
# 6   False   False    False         False          True     False  False
# 7   False   False    False          True         False     False  False
# 8   False   False    False         False         False     False   True
# 9   False   False    False         False          True     False  False
# 10  False   False    False          True         False     False  False

# %%
property_data.isna()
# Out:
#       lai  ST_NUM  ST_NAME  OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  SQ_FT
# 0   False   False    False         False         False     False  False
# 1   False   False    False         False         False     False   True
# 2   False   False    False         False          True     False  False
# 3   False   False    False         False         False      True  False
# 4   False   False    False         False         False      True  False
# 5   False   False    False         False         False     False  False
# 6   False   False    False         False          True     False  False
# 7   False   False    False          True         False     False  False
# 8   False   False    False         False         False     False   True
# 9   False   False    False         False          True     False  False
# 10  False   False    False          True         False     False  False

# %% [markdown]
# hasil fungsi `isna()` berupa nilai boolean yang merepresentasikan data yang memiliki nilai (Flase) dan missing value (True).

# %% [markdown]
# Hasil ini dapat diringkas/agregasi menggunakan fungsi aggregasi `.sum()` untuk menghitung jumlah missing value di tiap kolom.

# %%
# menghitung jumlah missing value pada tiap kolom
property_data.isna().sum()
# Out:
# lai             0
# ST_NUM          0
# ST_NAME         0
# OWN_OCCUPIED    2
# NUM_BEDROOMS    3
# NUM_BATH        2
# SQ_FT           2
# dtype: int64

# %% [markdown]
# hasil ringkasan juga dapat direpresentasikan dalam bentuk persentase

# %%
# menghitun jumlah missing value pada tiap kolom
property_data.isna().sum() / len(property_data)*100
# Out:
# lai              0.000000
# ST_NUM           0.000000
# ST_NAME          0.000000
# OWN_OCCUPIED    18.181818
# NUM_BEDROOMS    27.272727
# NUM_BATH        18.181818
# SQ_FT           18.181818
# dtype: float64

# %% [markdown]
# #### **Handle missing value**

# %% [markdown]
# Untuk menangani missing value, dapat dilakukan dengan beberapa cara:
#
# 1. Imputasi missing value
# 2. Drop kolom yang mengandung missing value

# %% [markdown]
# 1. Imputasi missing value \
# Menginput nilai pada missing value bergantung pada jenis data dari kolom yang mengandung NaN.
#
#      - Jika numeric dapat diinput dengan nilai mean, median atau modus.
#      - Jika kategorik dapat diinput dengan nilai modus, nilai tetangga terdekat atau diganti dengan nilai "Unknown"
#
#   Menginput missing value, dilakukan dengan menggunakan fungsi `.fillna`

# %%
# menampilkan data property
property_data
# Out:
#           lai  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  \
# 0   100001000     104      PUTNAM            Y           3.0       1.0
# 1   100002000     197         LXT            N           1.0       1.0
# 2   100003000     199   LEXINGTON            N           NaN       1.0
# 3   100004000     201    berkeley            Y           1.0       NaN
# 4   100004000     201    berkeley            Y           1.0       NaN
# 5   100005000     203    BERKELEY            Y           3.0       2.0
# 6   100006000     207    Berkeley            Y           NaN       1.0
# 7   100007000     209  WASHINGTON          NaN           2.0       1.0
# 8   100008000     213     TREMONT            Y           1.0       1.0
# 9   100009000     215     TREMONT            Y           NaN       2.0
# 10  100007000     209  WASHINGTON          NaN           2.0       1.0
#
#       SQ_FT
# 0     900.0
# 1       NaN
# 2     850.0
# 3     700.0
# 4     700.0
# 5     975.0
# 6     800.0
# 7     950.0
# 8       NaN
# 9   88000.0
# 10    950.0

# %%
# mengecek tipe data tiap kolom
property_data.dtypes
# Out:
# lai               int64
# ST_NUM            int64
# ST_NAME          object
# OWN_OCCUPIED     object
# NUM_BEDROOMS    float64
# NUM_BATH        float64
# SQ_FT           float64
# dtype: object

# %% [markdown]
# * Kolom `ST_NAME` dan `OWN_OCCUPIED` merupakan variable categorical
# * Kolom `NUM_BEDROOMS` dan `NUM_BATH` merupakan variabel numerical discrite
# * dan kolom `SQ_FT` merupakan kolom numerical continues

# %% [markdown]
# Dari hasil pengecekan sebelumnya kita akan menginputkan kolom `SQ_FT` dengan nilai median. Hal ini dilakukan karena pada kolom tersebut kemungkinan terdapat outlier.

# %%
# Menghitung nilai median dari kolom 'SQ_FT'
med_SQ = property_data["SQ_FT"].median()

# %%
# Mengisi nilai yang hilang dengan median
property_data["SQ_FT"].fillna(med_SQ)
# Out:
# 0       900.0
# 1       900.0
# 2       850.0
# 3       700.0
# 4       700.0
# 5       975.0
# 6       800.0
# 7       950.0
# 8       900.0
# 9     88000.0
# 10      950.0
# Name: SQ_FT, dtype: float64

# %%
# Menginput Nan pada kolom SQ_FT dengan nilai mean
property_data['SQ_FT'] = property_data['SQ_FT'].fillna(med_SQ)
property_data
# Out:
#           lai  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  \
# 0   100001000     104      PUTNAM            Y           3.0       1.0
# 1   100002000     197         LXT            N           1.0       1.0
# 2   100003000     199   LEXINGTON            N           NaN       1.0
# 3   100004000     201    berkeley            Y           1.0       NaN
# 4   100004000     201    berkeley            Y           1.0       NaN
# 5   100005000     203    BERKELEY            Y           3.0       2.0
# 6   100006000     207    Berkeley            Y           NaN       1.0
# 7   100007000     209  WASHINGTON          NaN           2.0       1.0
# 8   100008000     213     TREMONT            Y           1.0       1.0
# 9   100009000     215     TREMONT            Y           NaN       2.0
# 10  100007000     209  WASHINGTON          NaN           2.0       1.0
#
#       SQ_FT
# 0     900.0
# 1     900.0
# 2     850.0
# 3     700.0
# 4     700.0
# 5     975.0
# 6     800.0
# 7     950.0
# 8     900.0
# 9   88000.0
# 10    950.0

# %% [markdown]
# Untuk kolom `OWN_OCCUPIED, NUM_BEDROOMS dan NUM_BATH`, karena datanya numerical discrite dan kategori akan diganti dengan nilai modus.

# %%
# Mencari nilai modus dari kolom OWN_OCCUPIED, NUM_BEDROOMS dan NUM_BATH
mod_OWN_OCCUPIED = property_data["OWN_OCCUPIED"].mode()[0]
mod_NUM_BEDROOMS = property_data["NUM_BEDROOMS"].mode()[0]
mod_NUM_BATH = property_data["NUM_BATH"].mode()[0]

# %%
# Menginput NaN pada kolom OWN_OCCUPIED, NUM_BEDROOMS dan NUM_BATH
property_data["OWN_OCCUPIED"] = property_data["OWN_OCCUPIED"].fillna(mod_OWN_OCCUPIED)
property_data["NUM_BEDROOMS"] = property_data["NUM_BEDROOMS"].fillna(mod_NUM_BEDROOMS)
property_data["NUM_BATH"] = property_data["NUM_BATH"].fillna(mod_NUM_BATH)

# %%
# tampilkan data
property_data
# Out:
#           lai  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  \
# 0   100001000     104      PUTNAM            Y           3.0       1.0
# 1   100002000     197         LXT            N           1.0       1.0
# 2   100003000     199   LEXINGTON            N           1.0       1.0
# 3   100004000     201    berkeley            Y           1.0       1.0
# 4   100004000     201    berkeley            Y           1.0       1.0
# 5   100005000     203    BERKELEY            Y           3.0       2.0
# 6   100006000     207    Berkeley            Y           1.0       1.0
# 7   100007000     209  WASHINGTON            Y           2.0       1.0
# 8   100008000     213     TREMONT            Y           1.0       1.0
# 9   100009000     215     TREMONT            Y           1.0       2.0
# 10  100007000     209  WASHINGTON            Y           2.0       1.0
#
#       SQ_FT
# 0     900.0
# 1     900.0
# 2     850.0
# 3     700.0
# 4     700.0
# 5     975.0
# 6     800.0
# 7     950.0
# 8     900.0
# 9   88000.0
# 10    950.0

# %%
# cek lagi jika semua data sudah terhandle
property_data.isna().sum()
# Out:
# lai             0
# ST_NUM          0
# ST_NAME         0
# OWN_OCCUPIED    0
# NUM_BEDROOMS    0
# NUM_BATH        0
# SQ_FT           0
# dtype: int64

# %% [markdown]
# ### **Subtopik 2: Handling Outlier**

# %% [markdown]
# Selain menangani missing value, Rudi juga diminta untuk melakukan pengecekan outlier pada kolom data yang bertipe numerik.

# %%
# import library pandas
import pandas as pd

# %%
# read data property
property_data = pd.read_csv('https://raw.githubusercontent.com/ham407/Data-Cleansing-Using-Python/main/Datasets/property_without_nan.csv')

# %%
# menampilkan semua data property
property_data
# Out:
#           lai  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  \
# 0   100001000     104      PUTNAM            Y           3.0       1.0
# 1   100002000     197         LXT            N           1.0       1.0
# 2   100003000     199   LEXINGTON            N           1.0       1.0
# 3   100004000     201    berkeley            Y           1.0       1.0
# 4   100004000     201    berkeley            Y           1.0       1.0
# 5   100005000     203    BERKELEY            Y           3.0       2.0
# 6   100006000     207    Berkeley            Y           1.0       1.0
# 7   100007000     209  WASHINGTON            Y           2.0       1.0
# 8   100008000     213     TREMONT            Y           1.0       1.0
# 9   100009000     215     TREMONT            Y           1.0       2.0
# 10  100007000     209  WASHINGTON            Y           2.0       1.0
#
#       SQ_FT
# 0     900.0
# 1     900.0
# 2     850.0
# 3     700.0
# 4     700.0
# 5     975.0
# 6     800.0
# 7     950.0
# 8     900.0
# 9   88000.0
# 10    950.0

# %%
# menampilkan statistik deskriptif dari data
property_data.describe()
# Out:
#                 lai      ST_NUM  NUM_BEDROOMS   NUM_BATH         SQ_FT
# count  1.100000e+01   11.000000     11.000000  11.000000     11.000000
# mean   1.000051e+08  196.181818      1.545455   1.181818   8784.090909
# std    2.547726e+03   31.115328      0.820200   0.404520  26273.114282
# min    1.000010e+08  104.000000      1.000000   1.000000    700.000000
# 25%    1.000035e+08  200.000000      1.000000   1.000000    825.000000
# 50%    1.000050e+08  203.000000      1.000000   1.000000    900.000000
# 75%    1.000070e+08  209.000000      2.000000   1.000000    950.000000
# max    1.000090e+08  215.000000      3.000000   2.000000  88000.000000

# %% [markdown]
# Sekilah terlihat dari data diatas, pada kolom SQ_FT terdapat data yang nilainya jauh dari nilai kebanyakan data. Hal ini dapat diidentifikasi pada perbedaan nilai Q3 dan nilai maximum yang cukup jauh. Untuk melakukan pengecekan lebih lanjut, akan dilakukan visualisasi untuk melihat kemungkinan adanya outlier pada kolom SQ_FT

# %%
# menampilkan semua data property
property_data
# Out:
#           lai  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  \
# 0   100001000     104      PUTNAM            Y           3.0       1.0
# 1   100002000     197         LXT            N           1.0       1.0
# 2   100003000     199   LEXINGTON            N           1.0       1.0
# 3   100004000     201    berkeley            Y           1.0       1.0
# 4   100004000     201    berkeley            Y           1.0       1.0
# 5   100005000     203    BERKELEY            Y           3.0       2.0
# 6   100006000     207    Berkeley            Y           1.0       1.0
# 7   100007000     209  WASHINGTON            Y           2.0       1.0
# 8   100008000     213     TREMONT            Y           1.0       1.0
# 9   100009000     215     TREMONT            Y           1.0       2.0
# 10  100007000     209  WASHINGTON            Y           2.0       1.0
#
#       SQ_FT
# 0     900.0
# 1     900.0
# 2     850.0
# 3     700.0
# 4     700.0
# 5     975.0
# 6     800.0
# 7     950.0
# 8     900.0
# 9   88000.0
# 10    950.0

# %% [markdown]
# #### **Identifikasi Outlier**

# %% [markdown]
# Untuk melakukan visualisasi di python, dapat digunakan library seaborn. Visualisasi menggunakan seaborn dilakukan dengan memanggil fungsi-fungsi visualisasi yang sudah tersedia.
#
# Berikut contoh struktur untuk visualisasi dengan seaborn:
# <img src="https://drive.google.com/uc?export=view&id=12qGVWZqO2gaOJ_uLiIbc5XBovwV_Czmy" alt="Drawing" width= 300;/> \\

# %% [markdown]
# Outlier dapat diidentifikasi dengan melihat persebaran/distribusi dari data. Untuk menampilkan distribusi data pada sebuah kolom dapat digunakan histogram.

# %%
# Memanggil library seaborn
import seaborn as sns

# %%
# Membuat histogram SQ_FT
sns.histplot(data=property_data, x="SQ_FT", bins=100)
# Out:
# <Axes: xlabel='SQ_FT', ylabel='Count'>

# %% [markdown]
# Selain histogram, boxplot juga dapat digunakan untuk melihat sebaran data.

# %%
# Membuat boxplot SQ_FT
sns.boxplot(data=property_data, x='SQ_FT')
# Out:
# <Axes: xlabel='SQ_FT'>

# %% [markdown]
# Dari hasil visualisasi di atas, dapat dilihat terdapat outlier pada kolom SQ_FT.

# %% [markdown]
# #### **Handling Outlier**

# %% [markdown]
# Dari hasil identifikasi sebelumnya, diketahui terdapat outlier pada kolom SQ_FT. Outlier dapat ditangani dengan cara:
#
# 1. Menghapus data yang mengandung outlier, atau
# 2. Mengganti nilai outlier dengan statistik yang lebih representatif.
#
# Dalam pembelajaran ini, akan digunakan cara yang kedua.

# %% [markdown]
# Untuk mengganti nilai outlier, terlebih dahulu kita cari data yang lebih kecil dari **1.5*Q3** ([Batas atas nilai untuk mendeteksi outlier](https://towardsdatascience.com/why-1-5-in-iqr-method-of-outlier-detection-5d07fdc82097)).

# %%
# batas atas data
batas_atas = property_data["SQ_FT"].quantile(q=0.75) * 1.5

# plot tanpa outlier
property_without_outlier = property_data[property_data["SQ_FT"] < batas_atas]

# plot kolom SQ_FT tanpa extreme outlier
sns.histplot(property_without_outlier["SQ_FT"])
# Out:
# <Axes: xlabel='SQ_FT', ylabel='Count'>

# %% [markdown]
# Selanjutnya untuk mendapatkan hasil diatas, kita akan mengganti nilai outlier dengan nilai mediannya.

# %%
# batas atas data
batas_atas = property_data["SQ_FT"].quantile(q=0.75) * 1.5

# Mencari nilai median
median = property_data["SQ_FT"].median()

# mengubah nilai outlier dengan median
property_data.loc[property_data["SQ_FT"] > batas_atas, "SQ_FT"]= median
property_data
# Out:
#           lai  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  SQ_FT
# 0   100001000     104      PUTNAM            Y           3.0       1.0  900.0
# 1   100002000     197         LXT            N           1.0       1.0  900.0
# 2   100003000     199   LEXINGTON            N           1.0       1.0  850.0
# 3   100004000     201    berkeley            Y           1.0       1.0  700.0
# 4   100004000     201    berkeley            Y           1.0       1.0  700.0
# 5   100005000     203    BERKELEY            Y           3.0       2.0  975.0
# 6   100006000     207    Berkeley            Y           1.0       1.0  800.0
# 7   100007000     209  WASHINGTON            Y           2.0       1.0  950.0
# 8   100008000     213     TREMONT            Y           1.0       1.0  900.0
# 9   100009000     215     TREMONT            Y           1.0       2.0  900.0
# 10  100007000     209  WASHINGTON            Y           2.0       1.0  950.0

# %% [markdown]
# Setelah mengganti nilai outlier, kita bisa memvalidasi hasilnya dengan menampilkan sebaran dari datanya.

# %%
# histogram kolom SQ_FT
sns.histplot(property_data["SQ_FT"])
# Out:
# <Axes: xlabel='SQ_FT', ylabel='Count'>

# %%
sns.boxplot(property_data["SQ_FT"])
# Out:
# <Axes: ylabel='SQ_FT'>

# %% [markdown]
# ### **Subtopik 3 : Handling Duplicate**

# %% [markdown]
# Setelah menangani data outlier, Rudi diminta untuk mengecek apakah terdapat data duplikat pada dataset yang dimiliki.
#
# Data duplikat dikategorikan sebagai record data yang memiliki nilai yang sama dengan record lainnya.

# %% [markdown]
# #### **Identifikasi Duplikat**

# %% [markdown]
# Untuk mengidentifikasi duplikat, dapat digunakan method `duplicated()` dari object dataframe. Jika data tersebut memiliki nilai yang sama dengan record data sebelumnya, maka hasil pengecekannya bernilai `True`

# %%
# import library pandas
import pandas as pd

# read data property
property_data = pd.read_csv('https://raw.githubusercontent.com/ham407/Data-Cleansing-Using-Python/main/Datasets/property_without_outlier.csv')

# menampilkan semua data property
property_data
# Out:
#           lai  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  SQ_FT
# 0   100001000     104      PUTNAM            Y           3.0       1.0  900.0
# 1   100002000     197         LXT            N           1.0       1.0  900.0
# 2   100003000     199   LEXINGTON            N           1.0       1.0  850.0
# 3   100004000     201    berkeley            Y           1.0       1.0  700.0
# 4   100004000     201    berkeley            Y           1.0       1.0  700.0
# 5   100005000     203    BERKELEY            Y           3.0       2.0  975.0
# 6   100006000     207    Berkeley            Y           1.0       1.0  800.0
# 7   100007000     209  WASHINGTON            Y           2.0       1.0  950.0
# 8   100008000     213     TREMONT            Y           1.0       1.0  900.0
# 9   100009000     215     TREMONT            Y           1.0       2.0  900.0
# 10  100007000     209  WASHINGTON            Y           2.0       1.0  950.0

# %%
# Mengecek data duplikat
property_data.duplicated(keep=False)
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4      True
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10     True
# dtype: bool

# %%
# Menyeleksi data yang dikategorikan sebagai data diplikat
property_data[property_data.duplicated(keep=False)]
# Out:
#           lai  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  SQ_FT
# 3   100004000     201    berkeley            Y           1.0       1.0  700.0
# 4   100004000     201    berkeley            Y           1.0       1.0  700.0
# 7   100007000     209  WASHINGTON            Y           2.0       1.0  950.0
# 10  100007000     209  WASHINGTON            Y           2.0       1.0  950.0

# %% [markdown]
# #### **Handling Duplikat**

# %% [markdown]
# Menghilangkan record data yang duplikat dapat dilakukan dengan method `drop_duplicates()`. Pada method ini kita punya pilihan untuk:
#   - Mempertahankan record yang pertama, `keep='first'`
#   - Mempertahankan record yang terakhir, `keep='last'`
#   - Drop kedua data yang duplikat, `keep=False`
#
#
#   pada kasus ini kita akan mempertahankan record yang pertama

# %%
# Menghilangkan data duplikat
property_data = property_data.drop_duplicates(keep='last')
property_data
# Out:
#           lai  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  SQ_FT
# 0   100001000     104      PUTNAM            Y           3.0       1.0  900.0
# 1   100002000     197         LXT            N           1.0       1.0  900.0
# 2   100003000     199   LEXINGTON            N           1.0       1.0  850.0
# 4   100004000     201    berkeley            Y           1.0       1.0  700.0
# 5   100005000     203    BERKELEY            Y           3.0       2.0  975.0
# 6   100006000     207    Berkeley            Y           1.0       1.0  800.0
# 8   100008000     213     TREMONT            Y           1.0       1.0  900.0
# 9   100009000     215     TREMONT            Y           1.0       2.0  900.0
# 10  100007000     209  WASHINGTON            Y           2.0       1.0  950.0

# %% [markdown]
# ### **Subtopik 4 : Handling Inconsistent**

# %% [markdown]
# Untuk memastikan kualitas data saat dianalisis, pada tahapan terakhir Rudi diminta untuk memastikan tidak ada nilai yang inskonsisten didalam kolom.

# %% [markdown]
# Pengertian inskonsisten format yang dimaksud adalah data yang memiliki meaning yang sama namum penulisannya berbeda.
#
# Contoh pada kolom `ST_NAME`  nilai `berkeley`, `Berkeley` dan `BERKELEY` merujuk ke hal yang sama.
#
# Untuk memudahkan analisa, penulisan tersebut akan diseragamkan. Misal membuat semua nilai `berkeley`, `Berkeley` menjadi `BERKELEY`.

# %%
property_data
# Out:
#           lai  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  SQ_FT
# 0   100001000     104      PUTNAM            Y           3.0       1.0  900.0
# 1   100002000     197         LXT            N           1.0       1.0  900.0
# 2   100003000     199   LEXINGTON            N           1.0       1.0  850.0
# 4   100004000     201    berkeley            Y           1.0       1.0  700.0
# 5   100005000     203    BERKELEY            Y           3.0       2.0  975.0
# 6   100006000     207    Berkeley            Y           1.0       1.0  800.0
# 8   100008000     213     TREMONT            Y           1.0       1.0  900.0
# 9   100009000     215     TREMONT            Y           1.0       2.0  900.0
# 10  100007000     209  WASHINGTON            Y           2.0       1.0  950.0

# %%
# import library pandas
import pandas as pd

# read data property
property_data = pd.read_csv('https://raw.githubusercontent.com/ham407/Data-Cleansing-Using-Python/main/Datasets/property_without_duplicates.csv')

# menampilkan semua data property
property_data
# Out:
#          lai  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  SQ_FT
# 0  100001000     104      PUTNAM            Y           3.0       1.0  900.0
# 1  100002000     197         LXT            N           1.0       1.0  900.0
# 2  100003000     199   LEXINGTON            N           1.0       1.0  850.0
# 3  100004000     201    berkeley            Y           1.0       1.0  700.0
# 4  100005000     203    BERKELEY            Y           3.0       2.0  975.0
# 5  100006000     207    Berkeley            Y           1.0       1.0  800.0
# 6  100007000     209  WASHINGTON            Y           2.0       1.0  950.0
# 7  100008000     213     TREMONT            Y           1.0       1.0  900.0
# 8  100009000     215     TREMONT            Y           1.0       2.0  900.0

# %% [markdown]
# Pada data diatas dapat diidentifikasi terdapat format yang inkonsisten pada kolom ST_NAME. Kita akan identifikasi lebih lanjut dengan menggunakan beberapa cara.

# %% [markdown]
# #### **Identifikasi inkonsistensi**

# %% [markdown]
# Mengecek inkonsistensi dapat dilakukan dengan mengecek nilai unik pada kolom tersebut. Untuk mengecek nilai unik dapat digunakan method `unique()` pada kolom yang ingin dicek.

# %%
property_data['ST_NAME'].unique()
# Out:
# array(['PUTNAM', 'LXT', 'LEXINGTON', 'berkeley', 'BERKELEY', 'Berkeley',
#        'WASHINGTON', 'TREMONT'], dtype=object)

# %% [markdown]
# Alternatif lain dapat digunakan method `value_counts()`. Namun pada value counts selain menampilkan data unik, juga akan ditampilkan frekuensi kemunculan dari tiap data unik didalam kolom tersebut.

# %%
# Mengecek data uniq dan frekuensinya
property_data['ST_NAME'].value_counts()
# Out:
# TREMONT       2
# PUTNAM        1
# LXT           1
# LEXINGTON     1
# berkeley      1
# BERKELEY      1
# Berkeley      1
# WASHINGTON    1
# Name: ST_NAME, dtype: int64

# %% [markdown]
# #### **Handling inkonsistensi**
#
# Menangani data inkonsisten dapat dilakukan dengan penyeragaman. Sehingga perlu mengubah nilai yang memiliki meaning yang sama kedalam satu format.
#
# Hal ini dapat dilakukan dengan cara:
# 1. Melakukan mapping inkonsiten format ke bentuk yang diinginkan
# 2. Menggunakan hasil mapping untuk mengganti nilai yang inkonsisten

# %%
# mapping inkonsisten ke format yang benar
map_inkonsistent = {
    "LXT" : "LEXINGTON",
    "berkeley" : "BERKELEY",
    "Berkeley" : "BERKELEY",
}

# %% [markdown]
# Untuk mengganti nilai inkonsisten ke nilai yang benar, akan digunakan method `replace()`.
#
# Note: method replace digunakan karena data pada kolom ST_NAME bertipe string

# %%
# mengubah hasil mapping sehingga nilai menjadi seragam
property_data["ST_NAME"].replace(map_inkonsistent)
# Out:
# 0        PUTNAM
# 1     LEXINGTON
# 2     LEXINGTON
# 3      BERKELEY
# 4      BERKELEY
# 5      BERKELEY
# 6    WASHINGTON
# 7       TREMONT
# 8       TREMONT
# Name: ST_NAME, dtype: object

# %%
# menyimpan hasil perubahan ke data awal
property_data["ST_NAME"] = property_data["ST_NAME"].replace(map_inkonsistent)
property_data
# Out:
#          lai  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  SQ_FT
# 0  100001000     104      PUTNAM            Y           3.0       1.0  900.0
# 1  100002000     197   LEXINGTON            N           1.0       1.0  900.0
# 2  100003000     199   LEXINGTON            N           1.0       1.0  850.0
# 3  100004000     201    BERKELEY            Y           1.0       1.0  700.0
# 4  100005000     203    BERKELEY            Y           3.0       2.0  975.0
# 5  100006000     207    BERKELEY            Y           1.0       1.0  800.0
# 6  100007000     209  WASHINGTON            Y           2.0       1.0  950.0
# 7  100008000     213     TREMONT            Y           1.0       1.0  900.0
# 8  100009000     215     TREMONT            Y           1.0       2.0  900.0

# %% [markdown]
# Terlihat, setelah dirubah, data pada kolom ST_NAME menjadi seragam.

# %% [markdown]
# # **Handling Missing Values**

# %% [markdown]
# Data yang diperoleh dalam bentuk mentahan (raw), belum dapat di analisa / modelkan secara langsung karena memiliki beberapa permasalahan.
#
# 1. Terdapat missing value \
#    Missing value menandakan ketiadaan nilai. Hal ini berbeda dengan angka 0 atau string kosong (""). Missing value dapat disebabkan oleh beberapa hal:
#       - Kesalahan pengumpulan data
#       - Corrupt / error pada database
#       - Kesengajaan penghilangan data
#
# <img src="https://drive.google.com/uc?export=view&id=1GkOf6jiUQJOpNR2R5fd0yEFER4dSLW0R" alt="Drawing" width= 500px;/>
#
#  2. Terdapat Outlier \
#  Outlier merupakan nilai yang menyimpang dari rata-rata kebanyakan data.
#
# <img src="https://drive.google.com/uc?export=view&id=1aAyaBbnQ2Ywjcia-_NBW4k4lnkIWWSKO" alt="Drawing" width= 500px;/>
#
#  3. Terdapat data duplikat
#  Data duplikat terjadi karena adanya entry/record data yang sama
#
# <img src="https://drive.google.com/uc?export=view&id=1a6bAp_nOncXpgZdrHH0tHg-n_l4dyI9g" alt="Drawing" width= 500px;/>
#
#  4. Terdapat Inkonsistensi pada data \
#   Inkonsistensi direpresentasikan dengan data yang memiliki meaning yang sama namun ditulis secara berbeda.
#
# <img src="https://drive.google.com/uc?export=view&id=1q9EqPtG2yGRiPtFIMzVTOvS2QJNtLLa7" alt="Drawing" width= 500px;/>
#
# Permasalahan diatas, perlu di tangani terlebih dahulu sebelum masuk ke tahapan analisa / pemodelan data karena dapat berpengaruh ke hasil analisa dan interpretasi model. Pada materi kali ini, akan dipelajari cara menangani masalah pada data yang telah dijabarkan diatas

# %% [markdown]
# **Outline**
#
# - Handling NaN
# - Handling Outlier
# - Handling Duplicate
# - Handling Inkonsistent Format

# %% [markdown]
# ## **Topik**
# ---

# %% [markdown]
# ### **Subtopik 1 : Handling Missing Value**

# %% [markdown]
# Rudi bekerja sebagai analis di sebuah agen properti. Dia diminta untuk menganalisis data properti yang dimiliki oleh perusahaan. Namun sebelum melakukan analisis, dia diminta untuk membersihkan datanya terlebih dahulu agar hasil analisis bisa akurat.

# %%
# import library pandas
import pandas as pd

# %%
# read data property
property_data = pd.read_csv('https://raw.githubusercontent.com/ham407/Data-Cleansing-Using-Python/main/Datasets/property_data.csv')

# menampilkan semua data property
property_data
# Out:
#           lai  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  \
# 0   100001000     104      PUTNAM            Y           3.0       1.0
# 1   100002000     197         LXT            N           1.0       1.0
# 2   100003000     199   LEXINGTON            N           NaN       1.0
# 3   100004000     201    berkeley            Y           1.0       NaN
# 4   100004000     201    berkeley            Y           1.0       NaN
# 5   100005000     203    BERKELEY            Y           3.0       2.0
# 6   100006000     207    Berkeley            Y           NaN       1.0
# 7   100007000     209  WASHINGTON          NaN           2.0       1.0
# 8   100008000     213     TREMONT            Y           1.0       1.0
# 9   100009000     215     TREMONT            Y           NaN       2.0
# 10  100007000     209  WASHINGTON          NaN           2.0       1.0
#
#       SQ_FT
# 0     900.0
# 1       NaN
# 2     850.0
# 3     700.0
# 4     700.0
# 5     975.0
# 6     800.0
# 7     950.0
# 8       NaN
# 9   88000.0
# 10    950.0

# %% [markdown]
# Terlihat pada beberapa kolom berisi terdapat missing value (NaN). Sebelum menangani missing value, akan dilakukan pengecekan terlebih dahulu, untuk melihat persentase missing value di tiap kolom

# %% [markdown]
# #### **Identified Missing Value**
#
# Untuk mengecek missing value dapat dilakukan dengan method menggunakan `isna()` atau `isnull()`

# %%
# mengecek missing value pada property data
property_data.isna()
# Out:
#       lai  ST_NUM  ST_NAME  OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  SQ_FT
# 0   False   False    False         False         False     False  False
# 1   False   False    False         False         False     False   True
# 2   False   False    False         False          True     False  False
# 3   False   False    False         False         False      True  False
# 4   False   False    False         False         False      True  False
# 5   False   False    False         False         False     False  False
# 6   False   False    False         False          True     False  False
# 7   False   False    False          True         False     False  False
# 8   False   False    False         False         False     False   True
# 9   False   False    False         False          True     False  False
# 10  False   False    False          True         False     False  False

# %% [markdown]
# hasil fungsi `isna()` berupa nilai boolean yang merepresentasikan data yang memiliki nilai (False) dan missing value (True).
#
# Hasil ini dapat di ringkas/agregasi menggunakan fungsi aggregasi `.sum()` untuk menghitung jumlah missing value di tiap kolom.

# %%
# Menghitung jumlah missing value pada tiap kolom
property_data.isna().sum()
# Out:
# lai             0
# ST_NUM          0
# ST_NAME         0
# OWN_OCCUPIED    2
# NUM_BEDROOMS    3
# NUM_BATH        2
# SQ_FT           2
# dtype: int64

# %% [markdown]
# hasil ringkasan juga dapat direpresentasikan dalam bentuk persentase

# %%
# Menghitung jumlah missing value pada tiap kolom
property_data.isna().sum() / len(property_data) * 100
# Out:
# lai              0.000000
# ST_NUM           0.000000
# ST_NAME          0.000000
# OWN_OCCUPIED    18.181818
# NUM_BEDROOMS    27.272727
# NUM_BATH        18.181818
# SQ_FT           18.181818
# dtype: float64

# %% [markdown]
# #### **Handle Missing Value**
#
# Untuk menangani missing value, dapat dilakukan dengan beberapa cara:
# 1. Imputasi missing value
# 2. Drop kolom yang mengandung missing value

# %% [markdown]
# 1. Imputasi missing value \
# Menginput nilai pada missing value bergantung pada jenis data dari kolom yang mengandung NaN.
#
#      - Jika numeric dapat diinput dengan nilai mean, median atau modus.
#      - Jika kategorik dapat diinput dengan nilai modus, nilai tetangga terdekat atau diganti dengan nilai "Unknown"
#
#   Menginput missing value, dilakukan dengan menggunakan fungsi `.fillna`

# %%
# menampilkan data property
property_data
# Out:
#           lai  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  \
# 0   100001000     104      PUTNAM            Y           3.0       1.0
# 1   100002000     197         LXT            N           1.0       1.0
# 2   100003000     199   LEXINGTON            N           NaN       1.0
# 3   100004000     201    berkeley            Y           1.0       NaN
# 4   100004000     201    berkeley            Y           1.0       NaN
# 5   100005000     203    BERKELEY            Y           3.0       2.0
# 6   100006000     207    Berkeley            Y           NaN       1.0
# 7   100007000     209  WASHINGTON          NaN           2.0       1.0
# 8   100008000     213     TREMONT            Y           1.0       1.0
# 9   100009000     215     TREMONT            Y           NaN       2.0
# 10  100007000     209  WASHINGTON          NaN           2.0       1.0
#
#       SQ_FT
# 0     900.0
# 1       NaN
# 2     850.0
# 3     700.0
# 4     700.0
# 5     975.0
# 6     800.0
# 7     950.0
# 8       NaN
# 9   88000.0
# 10    950.0

# %%
# mengecek tipe data tiap kolom
property_data.dtypes
# Out:
# lai               int64
# ST_NUM            int64
# ST_NAME          object
# OWN_OCCUPIED     object
# NUM_BEDROOMS    float64
# NUM_BATH        float64
# SQ_FT           float64
# dtype: object

# %% [markdown]
# - Kolom `ST_NAME` dan `OWN_OCCUPIED` merupakan variabel categorical
# - Kolom `NUM_BEDROOMS` dan  `NUM_BATH` merupakan variabel numerical discrite
# - dan kolom `SQ_FT` merupakan kolom numerical continues

# %% [markdown]
# Dari hasil pengecekan sebelumnya kita akan menginput `SQ_FT` dengan nilai median. Hal ini dilakukan karena pada kolom tersebut kemungkinan terdapat outlier.

# %%
# menghitung nilai mean pada kolom SQ_FT
med_SQ = property_data['SQ_FT'].median()

# menginput NaN pada kolom SQ_FT dengan nilai mean
property_data['SQ_FT'] = property_data["SQ_FT"].fillna(med_SQ)

# tampilkan data
property_data
# Out:
#           lai  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  \
# 0   100001000     104      PUTNAM            Y           3.0       1.0
# 1   100002000     197         LXT            N           1.0       1.0
# 2   100003000     199   LEXINGTON            N           NaN       1.0
# 3   100004000     201    berkeley            Y           1.0       NaN
# 4   100004000     201    berkeley            Y           1.0       NaN
# 5   100005000     203    BERKELEY            Y           3.0       2.0
# 6   100006000     207    Berkeley            Y           NaN       1.0
# 7   100007000     209  WASHINGTON          NaN           2.0       1.0
# 8   100008000     213     TREMONT            Y           1.0       1.0
# 9   100009000     215     TREMONT            Y           NaN       2.0
# 10  100007000     209  WASHINGTON          NaN           2.0       1.0
#
#       SQ_FT
# 0     900.0
# 1     900.0
# 2     850.0
# 3     700.0
# 4     700.0
# 5     975.0
# 6     800.0
# 7     950.0
# 8     900.0
# 9   88000.0
# 10    950.0

# %%
property_data['SQ_FT'].fillna(med_SQ)
# Out:
# 0       900.0
# 1       900.0
# 2       850.0
# 3       700.0
# 4       700.0
# 5       975.0
# 6       800.0
# 7       950.0
# 8       900.0
# 9     88000.0
# 10      950.0
# Name: SQ_FT, dtype: float64

# %% [markdown]
# Untuk kolom `OWN_OCCUPIED, NUM_BEDROOMS dan NUM_BATH`, karena datanya numerical discrite dan kategori akan diganti dengan nilai modus.

# %%
# Mencari nilai modus dari kolom OWN_OCCUPIED, NUM_BEDROOMS dan NUM_BATH
mod_OWN_OCCUPIED = property_data["OWN_OCCUPIED"].mode()[0]
mod_NUM_BEDROOMS = property_data["NUM_BEDROOMS"].mode()[0]
mod_NUM_BATH = property_data["NUM_BATH"].mode()[0]

# Menginput NaN pada kolom OWN_OCCUPIED, NUM_BEDROOMS dan NUM_BATH dengan nilai modusnya masing-masing
property_data["OWN_OCCUPIED"] = property_data["OWN_OCCUPIED"].fillna(mod_OWN_OCCUPIED)
property_data["NUM_BEDROOMS"] = property_data["NUM_BEDROOMS"].fillna(mod_NUM_BEDROOMS)
property_data["NUM_BATH"] = property_data["NUM_BATH"].fillna(mod_NUM_BATH)
property_data
# Out:
#           lai  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  \
# 0   100001000     104      PUTNAM            Y           3.0       1.0
# 1   100002000     197         LXT            N           1.0       1.0
# 2   100003000     199   LEXINGTON            N           1.0       1.0
# 3   100004000     201    berkeley            Y           1.0       1.0
# 4   100004000     201    berkeley            Y           1.0       1.0
# 5   100005000     203    BERKELEY            Y           3.0       2.0
# 6   100006000     207    Berkeley            Y           1.0       1.0
# 7   100007000     209  WASHINGTON            Y           2.0       1.0
# 8   100008000     213     TREMONT            Y           1.0       1.0
# 9   100009000     215     TREMONT            Y           1.0       2.0
# 10  100007000     209  WASHINGTON            Y           2.0       1.0
#
#       SQ_FT
# 0     900.0
# 1     900.0
# 2     850.0
# 3     700.0
# 4     700.0
# 5     975.0
# 6     800.0
# 7     950.0
# 8     900.0
# 9   88000.0
# 10    950.0

# %%
# cek jika semua data sudah terhandle
property_data.isna().sum()
# Out:
# lai             0
# ST_NUM          0
# ST_NAME         0
# OWN_OCCUPIED    0
# NUM_BEDROOMS    0
# NUM_BATH        0
# SQ_FT           0
# dtype: int64

# %% [markdown]
# ### **Subtopik 2 : Handling Outlier**

# %% [markdown]
# Selain menangani missing value, Rudi juga diminta untuk melakukan pengecekan outlier pada kolom data yang bertipe numerik

# %%
# import library pandas
import pandas as pd

# read data property
property_data = pd.read_csv('https://raw.githubusercontent.com/ham407/Data-Cleansing-Using-Python/main/Datasets/property_without_nan.csv')

# menampilkan semua data property
property_data
# Out:
#           lai  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  \
# 0   100001000     104      PUTNAM            Y           3.0       1.0
# 1   100002000     197         LXT            N           1.0       1.0
# 2   100003000     199   LEXINGTON            N           1.0       1.0
# 3   100004000     201    berkeley            Y           1.0       1.0
# 4   100004000     201    berkeley            Y           1.0       1.0
# 5   100005000     203    BERKELEY            Y           3.0       2.0
# 6   100006000     207    Berkeley            Y           1.0       1.0
# 7   100007000     209  WASHINGTON            Y           2.0       1.0
# 8   100008000     213     TREMONT            Y           1.0       1.0
# 9   100009000     215     TREMONT            Y           1.0       2.0
# 10  100007000     209  WASHINGTON            Y           2.0       1.0
#
#       SQ_FT
# 0     900.0
# 1     900.0
# 2     850.0
# 3     700.0
# 4     700.0
# 5     975.0
# 6     800.0
# 7     950.0
# 8     900.0
# 9   88000.0
# 10    950.0

# %%
# menampilkan statistik deskriptif dari data
property_data.describe()
# Out:
#                 lai      ST_NUM  NUM_BEDROOMS   NUM_BATH         SQ_FT
# count  1.100000e+01   11.000000     11.000000  11.000000     11.000000
# mean   1.000051e+08  196.181818      1.545455   1.181818   8784.090909
# std    2.547726e+03   31.115328      0.820200   0.404520  26273.114282
# min    1.000010e+08  104.000000      1.000000   1.000000    700.000000
# 25%    1.000035e+08  200.000000      1.000000   1.000000    825.000000
# 50%    1.000050e+08  203.000000      1.000000   1.000000    900.000000
# 75%    1.000070e+08  209.000000      2.000000   1.000000    950.000000
# max    1.000090e+08  215.000000      3.000000   2.000000  88000.000000

# %% [markdown]
# Sekilas terlihat dari data diatas, pada kolom SQ_FT terdapat data yang nilainya jauh dari nilai kebanyakan data. Hal ini dapat diidentifikasi pada perbedaan nilai Q3 dan nilai maximum yang cukup jauh. Untuk melakukan pengecekan lebih lanjut, akan dilakukan visualisasi untuk melihat kemungkinan adanya outlier pada kolom SQ_FT

# %%
property_data
# Out:
#           lai  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  \
# 0   100001000     104      PUTNAM            Y           3.0       1.0
# 1   100002000     197         LXT            N           1.0       1.0
# 2   100003000     199   LEXINGTON            N           1.0       1.0
# 3   100004000     201    berkeley            Y           1.0       1.0
# 4   100004000     201    berkeley            Y           1.0       1.0
# 5   100005000     203    BERKELEY            Y           3.0       2.0
# 6   100006000     207    Berkeley            Y           1.0       1.0
# 7   100007000     209  WASHINGTON            Y           2.0       1.0
# 8   100008000     213     TREMONT            Y           1.0       1.0
# 9   100009000     215     TREMONT            Y           1.0       2.0
# 10  100007000     209  WASHINGTON            Y           2.0       1.0
#
#       SQ_FT
# 0     900.0
# 1     900.0
# 2     850.0
# 3     700.0
# 4     700.0
# 5     975.0
# 6     800.0
# 7     950.0
# 8     900.0
# 9   88000.0
# 10    950.0

# %% [markdown]
# #### Identifikasi outlier

# %% [markdown]
# Untuk melakukan visualisasi di python, dapat digunakan library seaborn. Visualisasi menggunakan seaborn dilakukan dengan memanggil fungsi-fungsi visualisasi yang sudah tersedia. Berikut contoh struktur untuk visualisasi menggunakan seaborn:
#
# <img src="https://drive.google.com/uc?export=view&id=12qGVWZqO2gaOJ_uLiIbc5XBovwV_Czmy" alt="Drawing" width= 300;/> \\

# %% [markdown]
# Outlier dapat diidentifikasi dengan melihat sebaran/distribusi dari data. Untuk menampilkan distribusi data pada sebuah kolom dapat digunakan histogram.

# %%
# Memanggil library seaborn
import seaborn as sns

# %%
# Membuat histogram SQ_FT
sns.histplot(data=property_data,x="SQ_FT", bins=100)
# Out:
# <Axes: xlabel='SQ_FT', ylabel='Count'>

# %% [markdown]
# Selain histogram, boxplot juga dapat digunakan untuk melihat sebaran data.

# %%
# Membuat boxplot SQ_FT
sns.boxplot(data=property_data,x="SQ_FT")
# Out:
# <Axes: xlabel='SQ_FT'>

# %% [markdown]
# Dari hasil visualisasi di atas, dapat dilihat terdapat outlier pada kolom SQ_FT.

# %% [markdown]
# #### Handling Outlier

# %% [markdown]
# Dari hasil identifikasi sebelumnya, diketahui terdapat outlier pada kolom SQ_FT. Outlier dapat ditangani dengan cara:
# 1. Mengahapus data yang mengandung outlier, atau
# 2. Menganti nilai outlier dengan nilai statistik yang lebih representatif.  [(Aguinas et al., 2013)](http://www.hermanaguinis.com/ORMoutliers.pdf)
#
#
#
# Dalam pembelajaran ini, akan digunakan cara yang kedua

# %% [markdown]
# Untuk mengganti nilai outlier, terlebih dahulu kita cari data yang lebih kecil dari **1.5*Q3** ([Batas atas nilai untuk mendeteksi outlier](https://towardsdatascience.com/why-1-5-in-iqr-method-of-outlier-detection-5d07fdc82097)).

# %%
# batas atas data
batas_atas = property_data["SQ_FT"].quantile(q=0.75) * 1.5

# plot tanpa outlier
property_without_outlier = property_data[property_data["SQ_FT"] < batas_atas]

# plot kolom SQ_FT tanpa extreme outlier
sns.histplot(property_without_outlier["SQ_FT"])
# Out:
# <Axes: xlabel='SQ_FT', ylabel='Count'>

# %% [markdown]
# Selanjutnya untuk mendapatkan hasil diatas, kita akan mengganti nilai outlier dengan nilai mediannya.

# %%
# batas atas data
batas_atas = property_data["SQ_FT"].quantile(q=0.75) * 1.5

# Mencari nilai median
median = property_data["SQ_FT"].median()

# mengubah nilai outlier dengan median
property_data.loc[property_data["SQ_FT"] > batas_atas, "SQ_FT"]= median
property_data
# Out:
#           lai  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  SQ_FT
# 0   100001000     104      PUTNAM            Y           3.0       1.0  900.0
# 1   100002000     197         LXT            N           1.0       1.0  900.0
# 2   100003000     199   LEXINGTON            N           1.0       1.0  850.0
# 3   100004000     201    berkeley            Y           1.0       1.0  700.0
# 4   100004000     201    berkeley            Y           1.0       1.0  700.0
# 5   100005000     203    BERKELEY            Y           3.0       2.0  975.0
# 6   100006000     207    Berkeley            Y           1.0       1.0  800.0
# 7   100007000     209  WASHINGTON            Y           2.0       1.0  950.0
# 8   100008000     213     TREMONT            Y           1.0       1.0  900.0
# 9   100009000     215     TREMONT            Y           1.0       2.0  900.0
# 10  100007000     209  WASHINGTON            Y           2.0       1.0  950.0

# %% [markdown]
# Setelah mengganti nilai outlier, kita bisa memvalidasi hasilnya dengan menampilkan sebaran dari datanya.

# %%
# histogram kolom SQ_FT
sns.histplot(property_data["SQ_FT"])
# Out:
# <Axes: xlabel='SQ_FT', ylabel='Count'>

# %% [markdown]
# ### **Subtopik 3 : Handling Duplicated**

# %% [markdown]
# Setelah menangani data oulier, Rudi diminta untuk mengecek apakah terdapat data duplikat pada dataset yang dimiliki.
#
# Data duplikat dikategoriukan seabagai record data yang memiliki nilai yang sama dengan record lainnya.

# %% [markdown]
# #### Identifikasi Duplikat

# %% [markdown]
# Untuk mengidentifikasi duplikat, dapat digunakan method `duplicated()` dari object dataframe. Jika data tersebut memiliki nilai yang sama dengan record data sebelumnya, maka hasil pengecekannya bernilai `True`

# %%
# import library pandas
import pandas as pd

# read data property
property_data = pd.read_csv('https://raw.githubusercontent.com/ham407/Data-Cleansing-Using-Python/main/Datasets/property_without_outlier.csv')

# menampilkan semua data property
property_data
# Out:
#           lai  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  SQ_FT
# 0   100001000     104      PUTNAM            Y           3.0       1.0  900.0
# 1   100002000     197         LXT            N           1.0       1.0  900.0
# 2   100003000     199   LEXINGTON            N           1.0       1.0  850.0
# 3   100004000     201    berkeley            Y           1.0       1.0  700.0
# 4   100004000     201    berkeley            Y           1.0       1.0  700.0
# 5   100005000     203    BERKELEY            Y           3.0       2.0  975.0
# 6   100006000     207    Berkeley            Y           1.0       1.0  800.0
# 7   100007000     209  WASHINGTON            Y           2.0       1.0  950.0
# 8   100008000     213     TREMONT            Y           1.0       1.0  900.0
# 9   100009000     215     TREMONT            Y           1.0       2.0  900.0
# 10  100007000     209  WASHINGTON            Y           2.0       1.0  950.0

# %%
# mengecek data duplikat
property_data.duplicated(keep=False)
# Out:
# 0     False
# 1     False
# 2     False
# 3      True
# 4      True
# 5     False
# 6     False
# 7      True
# 8     False
# 9     False
# 10     True
# dtype: bool

# %%
# menyeleksi data yang dikategorikan sebagai data duplikat
property_data[property_data.duplicated(keep=False)]
# Out:
#           lai  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  SQ_FT
# 3   100004000     201    berkeley            Y           1.0       1.0  700.0
# 4   100004000     201    berkeley            Y           1.0       1.0  700.0
# 7   100007000     209  WASHINGTON            Y           2.0       1.0  950.0
# 10  100007000     209  WASHINGTON            Y           2.0       1.0  950.0

# %% [markdown]
# #### Handling Duplikat

# %% [markdown]
# Menghilangkan record data yang duplikat dapat dilakukan dengan method `drop_duplicates()`. Pada method ini kita punya pilihan untuk:
#   - Mempertahankan record yang pertama, `keep='first'`
#   - Mempertahankan record yang terakhir, `keep='last'`
#   - Drop kedua data yang duplikat, `keep=False`
#
#
#   pada kasus ini kita akan mempertahankan record yang pertama

# %%
# menghilangkan data duplikat
property_data = property_data.drop_duplicates(keep='last')

# %%
property_data
# Out:
#           lai  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  SQ_FT
# 0   100001000     104      PUTNAM            Y           3.0       1.0  900.0
# 1   100002000     197         LXT            N           1.0       1.0  900.0
# 2   100003000     199   LEXINGTON            N           1.0       1.0  850.0
# 4   100004000     201    berkeley            Y           1.0       1.0  700.0
# 5   100005000     203    BERKELEY            Y           3.0       2.0  975.0
# 6   100006000     207    Berkeley            Y           1.0       1.0  800.0
# 8   100008000     213     TREMONT            Y           1.0       1.0  900.0
# 9   100009000     215     TREMONT            Y           1.0       2.0  900.0
# 10  100007000     209  WASHINGTON            Y           2.0       1.0  950.0

# %% [markdown]
# ### **Subtopik 4 : Handling Inconsistent**

# %% [markdown]
# Untuk memastikan kualitas data saat dianalisis, pada tahap terakhir Rudi diminta untuk memastikan tidak ada nilai yang inkonsisten di dalam kolom.
